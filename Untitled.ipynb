# %%
f(x)=sin(x)
@interact
def _(a=input_box(2)):
    P1=plot(f(x),x,-pi,pi,color="red",figsize=(3,2))
    P2=plot(f(x-a),x,-pi,pi,color="blue",figsize=(3,2))
    show(P1+P2)
# Out:
# Graphics object consisting of 2 graphics primitives
